# %% [markdown]
# # Mean-Variance-Standard Deviation Calculator

# %% [markdown]
# Create a function named calculate() in mean_var_std.py that uses Numpy to output the mean, variance, standard deviation, max, min, and sum of the rows, columns, and elements in a 3 x 3 matrix.
#
# The input of the function should be a list containing 9 digits. The function should convert the list into a 3 x 3 Numpy array, and then return a dictionary containing the mean, variance, standard deviation, max, min, and sum along both axes and for the flattened matrix.
#
# The returned dictionary should follow this format:
#
#
# ![image.png](attachment:image.png)
#
#
# If a list containing less than 9 elements is passed into the function, it should raise a ValueError exception with the message: "List must contain nine numbers." The values in the returned dictionary should be lists and not Numpy arrays.

# %% [markdown]
# # Solution

# %%
from numpy.core.fromnumeric import mean
import numpy as np

def calculate(arrayy):
    lst = np.array(arrayy)
    lst_size = lst.size
    while lst_size != 9:
        input_string = input("ValueError\nList must contain nine numbers!!\nEnter a list element separated by space: ")
        lst  = np.array(input_string.split()).astype(float)
        lst_size = lst.size
    
    lst = np.matrix(lst.reshape((3,3)))
    mean_rows = [lst[:, 0].mean(), lst[:, 1].mean(), lst[:, 2].mean()]
    var_rows = [lst[:, 0].var(), lst[:, 1].var(), lst[:, 2].var()]
    std_rows = [lst[:, 0].std(), lst[:, 1].std(), lst[:, 2].std()]
    max_rows = [lst[:, 0].max(), lst[:, 1].max(), lst[:, 2].max()]
    min_rows = [lst[:, 0].min(), lst[:, 1].min(), lst[:, 2].min()]

    mean_colm = [lst[0, :].mean(), lst[1, :].mean(), lst[2, :].mean()]
    var_colm = [lst[0, :].var(), lst[1, :].var(), lst[2, :].var()]
    std_colm = [lst[0, :].std(), lst[1, :].std(), lst[2, :].std()]
    max_colm = [lst[0, :].max(), lst[1, :].max(), lst[2, :].max()]
    min_colm = [lst[0, :].min(), lst[1, :].min(), lst[2, :].min()]

    return{
        "mean": [mean_rows, mean_colm, lst.mean()],
        "variance": [var_rows, var_colm, lst.var()],
        "standar deviation": [std_rows, std_colm, lst.std()],
         'max': [max_rows, max_colm, lst.max()],
         'min': [min_rows, min_colm, lst.min()],
    }



calculate([0,1,2,3,4,5,6])
# Out:
# ValueError
# List must contain nine numbers!!
# Enter a list element separated by space: 0 1 2 3 4 5 6 7 8
# {'mean': [[3.0, 4.0, 5.0], [1.0, 4.0, 7.0], 4.0],
#  'variance': [[6.0, 6.0, 6.0],
#   [0.6666666666666666, 0.6666666666666666, 0.6666666666666666],
#   6.666666666666667],
#  'standar deviation': [[2.449489742783178,
#    2.449489742783178,
#    2.449489742783178],
#   [0.816496580927726, 0.816496580927726, 0.816496580927726],
#   2.581988897471611],
#  'max': [[6.0, 7.0, 8.0], [2.0, 5.0, 8.0], 8.0],
#  'min': [[0.0, 1.0, 2.0], [0.0, 3.0, 6.0], 0.0]}
